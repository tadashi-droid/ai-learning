# %% [markdown]
# <a href="https://colab.research.google.com/github/tadashi-droid/ai-learning/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# データ準備
data = load_iris()
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, test_size=0.2, random_state=42)

# モデル訓練
model = RandomForestClassifier()
model.fit(X_train, y_train)

# 精度確認
pred = model.predict(X_test)
print("精度：", accuracy_score(y_test, pred))
# Out:
# 精度： 1.0
